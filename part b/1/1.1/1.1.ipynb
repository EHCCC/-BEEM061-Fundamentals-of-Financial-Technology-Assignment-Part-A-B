# %%
import json 
import requests

# %%
blockchain = requests.get("https://api.whatsonchain.com/v1/bsv/main/block/height/736669")

# %%
data = json.loads(blockchain.text)

# %%
data
# Out:
# {'hash': '000000000000000009f1ccceb83bc41ad10d795bcdfcf1b319cf3c7dbbce68dd',
#  'confirmations': 537,
#  'size': 1477408,
#  'height': 736669,
#  'version': 536870912,
#  'versionHex': '20000000',
#  'merkleroot': '0e3dcb91180f9251dcbe4c4d59078691e3747ccafafb931892e826bad3b2c49a',
#  'txcount': 489,
#  'nTx': 0,
#  'num_tx': 489,
#  'tx': ['fb4a65c39cedab3e3249861d8ca26be1b5e04f682c5d378e2b221030527fdcdc',
#   '8633a8e92f7e82d58ed07354fb068ddf930f20a46717954812016e1d47fe5fb7',
#   'e741014d6a0ca2cce5c017c44e549ddcd18c08dd92e4d5e409c5b789a6df0a84',
#   'c56010bf37c6022a7d508f04ac1a92867848f38bcdd725e3a30ae9cd29b0e16a',
#   'ff73e00ea59173943e145a1b7dd8c900ac2e3f52160e56afc36c176f9350841c',
#   'fdc7c74ae7887639c3f13f8c36e20387c944e7e4085939b96a8e21489a35f712',
#   'a2587b251cef91036bc5bbef1a252236f34b57a76b45bbf7addbb37d88364912',
#   '5fe1c0c3bb10d1bdeeb158649b8098696cd1dd6ec2f04ecae2a4574326a3c039',
#   '4983bd806ebc5d3c35b925fb9599526f3fad06faaf7deb42fe499e1d934077c9',
# ...

# %%
import datetime

# %%
timestamp = datetime.datetime.fromtimestamp(data['time'])

# %%
hunman_read_time = timestamp.strftime('%Y-%m-%d %H:%M:%S')

# %%
hunman_read_time
# Out:
# '2022-04-25 09:10:13'

# %%
#txcount indicates the number of transactions that occurred on the public blockchain in a day. On April 25, 2022, 489 BSV transactions occurred
# time tells us when the transaction occurred on 2022-04-25
# totalFees is the sum of the transaction fees generated by all transactions that occurred on that day of 0.006728
# comfirmations indicates the number of connected blocks after this block is 537.
# miner is the person or organization that created this block as "SBICrypto.com".

Translated with www.DeepL.com/Translator (free version)
